# %%
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# %% [markdown]
# # 1. The given dataset "Parkinson_Dataset_2" contains data from class 0 and 1. Split the dataset into 90:10 train -test ratio.

# %%
data1 = pd.read_csv('Parkinson_Dataset_2.csv')
data1.describe()
# Out:
#        Unnamed: 0          id      gender         PPE         DFA        RPDE  \
# count  502.000000  502.000000  502.000000  502.000000  502.000000  502.000000
# mean   250.500000  129.460199    0.478827    0.751966    0.689127    0.460969
# std    145.059183   70.315638    0.490080    0.164055    0.070627    0.139770
# min      0.000000    1.000000    0.000000    0.103480    0.545320    0.178730
# 25%    125.250000   68.663178    0.000000    0.772241    0.635604    0.354044
# 50%    250.500000  131.887552    0.108133    0.811016    0.683755    0.459582
# 75%    375.750000  190.000000    1.000000    0.832601    0.742054    0.568585
# max    501.000000  251.000000    1.000000    0.907660    0.852640    0.871230
#
#         numPulses  numPeriodsPulses  meanPeriodPulses  stdDevPeriodPulses  \
# count  502.000000        502.000000        502.000000          502.000000
# mean   344.339682        343.164456          0.006059            0.000311
# std    117.589138        117.660877          0.001817            0.000604
# min      2.000000          1.000000          0.002107            0.000014
# 25%    260.250000        259.250000          0.004612            0.000042
# 50%    321.500000        320.500000          0.005985            0.000075
# 75%    413.507260        412.274600          0.007225            0.000160
# max    907.000000        905.000000          0.012026            0.003327
#
#        ...  tqwt_kurtosisValue_dec_28  tqwt_kurtosisValue_dec_29  \
# count  ...                 502.000000                 502.000000
# mean   ...                  31.736402                  25.672164
# std    ...                  46.345295                  34.976624
# min    ...                   1.509800                   1.553400
# 25%    ...                   2.807525                   3.790811
# 50%    ...                   7.833000                   9.049727
# 75%    ...                  49.075801                  33.964525
# max    ...                 239.788800                 203.311300
#
#        tqwt_kurtosisValue_dec_30  tqwt_kurtosisValue_dec_31  \
# count                 502.000000                 502.000000
# mean                   19.171096                  13.652520
# std                    26.120698                  19.523786
# min                     1.582900                   2.063700
# 25%                     3.454060                   3.175325
# 50%                     6.697516                   4.882567
# 75%                    21.226818                  13.185075
# max                   121.542900                 100.706500
#
#        tqwt_kurtosisValue_dec_32  tqwt_kurtosisValue_dec_33  \
# count                 502.000000                 502.000000
# mean                   11.760112                  11.097745
# std                    17.157591                  14.867368
# min                     1.789500                   1.812200
# 25%                     2.969945                   3.120450
# 50%                     4.738796                   4.909865
# 75%                     9.612801                   9.866839
# max                    82.750200                  73.532200
#
#        tqwt_kurtosisValue_dec_34  tqwt_kurtosisValue_dec_35  \
# count                 502.000000                 502.000000
# mean                   13.595623                  13.523645
# std                    14.601797                  13.630522
# min                     1.861700                   1.991000
# 25%                     3.699550                   3.852213
# 50%                     6.532733                   6.623568
# 75%                    17.541457                  18.832823
# max                    61.595200                  57.544300
#
#        tqwt_kurtosisValue_dec_36       class
# count                 502.000000  502.000000
# mean                   26.077778    0.462151
# std                    31.652532    0.499063
# min                     2.489600    0.000000
# 25%                     3.959007    0.000000
# 50%                     7.770441    0.000000
# 75%                    42.977138    1.000000
# max                   156.423700    1.000000
#
# [8 rows x 756 columns]

# %%
X = data1.drop('class', axis=1)
y = data1['class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

# %%
lda = LDA(n_components=1)

# %% [markdown]
# # 2. Perform LDA on the dataset on the 90% split

# %%
lda.fit(X_train, y_train)
# Out:
# LinearDiscriminantAnalysis(n_components=1)

# %% [markdown]
# # 3. Test the accuracy on the 10% split.

# %%
lda.score(X_test, y_test)
# Out:
# 0.7647058823529411
